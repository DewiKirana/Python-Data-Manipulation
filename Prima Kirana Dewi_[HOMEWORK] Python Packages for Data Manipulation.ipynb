# %% [markdown]
# ### Homework - Python Packages for Data Manipulation

# %% [markdown]
# ![FIFA](https://www.fifplay.com/img/public/fifa-20-logo.png)

# %% [markdown]
# ##### Petunjuk pengambilan dataset untuk PR
#
# 1. Download dataset dibawah
#
# __[fifa dataset](https://www.kaggle.com/stefanoleone992/fifa-20-complete-player-dataset)__
#
# 2. setelah di download unzip atau extract file sehingga akan muncul 7 file csv
# - players_15.csv
# - players_16.csv
# - players_17.csv
# - players_18.csv
# - players_19.csv
# - players_20.csv
# - teams_and_leagues.csv
#
# 3. Gunakan dataset 'players_20.csv' untuk mengerjakan 6 soal yang ada dibawah ini
#
# 4. Terdapat soal ke 7 di akhir bagi teman-teman yang ingin menambah nilai (jika dirasa tidak yakin dengan jawaban soal nomer 1-6 dan khawatir nilai nya kecil)
#
# 5. Soal nomer 7 merupakan optional
#
# Good Luck!

# %% [markdown]
# 1. Buatlah dataframe yang disimpan dalam variabel 'df_england', yang merupakan data pemain dengan kewarganegaraan England

# %%
import pandas as pd
path = 'D:/Data Science Bootcamp/Homework/Python_Library/'
data = pd.read_csv(path + 'players_20.csv')

pd.set_option('display.max_columns', 100)
data.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  overall  potential  \
# ...

# %%
df_england = data[(data['nationality']=='England')].reset_index()

# %%
df_england   #ada 1667 pemain yang berasal dari England
# Out:
#       index  sofifa_id                                         player_url  \
# 0        12     202126  https://sofifa.com/player/202126/harry-kane/20...
# 1        26     202652  https://sofifa.com/player/202652/raheem-sterli...
# 2       108     233049  https://sofifa.com/player/233049/jadon-sancho/...
# 3       113     211117  https://sofifa.com/player/211117/dele-alli/20/...
# 4       148     188377  https://sofifa.com/player/188377/kyle-walker/2...
# ...     ...        ...                                                ...
# 1662  18253     250739  https://sofifa.com/player/250739/nathan-morley...
# 1663  18255     252548  https://sofifa.com/player/252548/connor-heath/...
# 1664  18256     241493  https://sofifa.com/player/241493/samuel-cartwr...
# 1665  18265     241828  https://sofifa.com/player/241828/luke-offord/2...
# 1666  18270     252568  https://sofifa.com/player/252568/mohammed-saga...
#
#          short_name          long_name  age         dob  height_cm  weight_kg  \
# ...

# %% [markdown]
# 2. Ada berapa total pemain berkewarganegaraan France?

# %%
len(data[(data['nationality']=='France')])
# Out:
# 984

# %%
df_france = data[(data['nationality']=='France')].reset_index()
df_france
# Out:
#      index  sofifa_id                                         player_url  \
# 0       10     231747  https://sofifa.com/player/231747/kylian-mbappe...
# 1       15     215914  https://sofifa.com/player/215914/ngolo-kante/2...
# 2       22     194765  https://sofifa.com/player/194765/antoine-griez...
# 3       24     195864  https://sofifa.com/player/195864/paul-pogba/20...
# 4       32     167948  https://sofifa.com/player/167948/hugo-lloris/2...
# ..     ...        ...                                                ...
# 979  17871     252078  https://sofifa.com/player/252078/samuel-loric/...
# 980  17917     252047  https://sofifa.com/player/252047/yohan-bilingi...
# 981  18015     248719  https://sofifa.com/player/248719/wassim-aouach...
# 982  18024     251142  https://sofifa.com/player/251142/lucas-marsell...
# 983  18113     243711  https://sofifa.com/player/243711/thomas-callen...
#
#        short_name          long_name  age         dob  height_cm  weight_kg  \
# ...

# %% [markdown]
# 3. siapakah 5 pemain degan nilai overall terendah

# %%
df_small = data.sort_values(by='overall').reset_index().loc[:4, ['short_name', 'long_name', 'overall']]
df_small
# Out:
#            short_name               long_name  overall
# 0          Pan Ximing                     潘喜明       48
# 1         A. Aksungur           Asim Aksungur       48
# 2  G. Sykes-Kenworthy  George Sykes-Kenworthy       48
# 3           R. Roache            Rowan Roache       48
# 4       Shan Huanhuan                     单欢欢       48

# %%
len(data[(data['overall']== 48)])
# Out:
# 43

# %% [markdown]
# 4. Buatlah kolom "duration contract" yang merupakan selisih antara tahun dimana pemain bergabung sampai tahun dimana contract berakhir
#
# Hints : Buatlah terlebih dahulu kolom baru yang merupakan tahun dimana pemain mulai bergabung

# %%
data['joined'] = pd.to_datetime(data['joined'])
data['year'] = data['joined'].dt.year
data['year']
# Out:
# 0        2004.0
# 1        2018.0
# 2        2017.0
# 3        2014.0
# 4        2019.0
#           ...
# 18273    2018.0
# 18274    2019.0
# 18275    2019.0
# 18276    2019.0
# 18277       NaN
# Name: year, Length: 18278, dtype: float64

# %%
data.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  overall  potential  \
# ...

# %%
data['duration contract'] = data['contract_valid_until'] - data['year']
data.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  overall  potential  \
# ...

# %% [markdown]
# 5. Buatlah kolom baru yang bernama "players category" yang berisi kategori players sebagai berikut :
# - "Legend" : Jika overall bernilai lebih dari 90
# - "High Class" : Jika overall bernilai dari 80 sampai 90
# - "Great" : Jika overall bernilai dari 70 sampai 80
# - "Average" : Jika overall bernilai dari 60 sampai 70
# - "Low Class" : Jika overall bernilai dari 50 sampai 60
# - "Bottom Class" : Jika overall bernilai dibawah 50

# %%
def ply_cat(x):
    if x['overall'] > 90:
        cat = 'Legend'
    elif x['overall'] > 80 and x['overall'] <=90:
        cat = 'High Class'
    elif x['overall'] > 70 and x['overall'] <=80:
        cat = 'Great' 
    elif x['overall'] > 60 and x['overall'] <=70:
        cat = 'Average'
    elif x['overall'] >=50 and x['overall'] <=60:
        cat = 'Low Class'
    elif x['overall'] <50 :
        cat = 'Bottom Class'
    return cat

data['players category'] = data.apply(lambda x: ply_cat(x), axis=1)

# %%
data.head(10)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
# 5     192985  https://sofifa.com/player/192985/kevin-de-bruy...
# 6     192448  https://sofifa.com/player/192448/marc-andre-te...
# 7     203376  https://sofifa.com/player/203376/virgil-van-di...
# 8     177003  https://sofifa.com/player/177003/luka-modric/2...
# 9     209331  https://sofifa.com/player/209331/mohamed-salah...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# ...

# %% [markdown]
# 6. Ada berapakah pemain England yang masuk kategori "Bottom Class" ?

# %%
len(data[(data['players category']== 'Bottom Class') & (data['nationality']=='England')])
# Out:
# 38

# %%
df_england_bottom = (data[(data['players category']== 'Bottom Class') & (data['nationality']=='England')]).reset_index()
df_england_bottom
# Out:
#     index  sofifa_id                                         player_url  \
# 0   18170     252828  https://sofifa.com/player/252828/demarlio-brow...
# 1   18171     252892  https://sofifa.com/player/252892/joseph-starbu...
# 2   18172     248815  https://sofifa.com/player/248815/kevin-berkoe/...
# 3   18174     252889  https://sofifa.com/player/252889/josh-galloway...
# 4   18176     246648  https://sofifa.com/player/246648/ollie-batters...
# 5   18179     250812  https://sofifa.com/player/250812/ruel-sotiriou...
# 6   18180     251265  https://sofifa.com/player/251265/nathan-shaw/2...
# 7   18182     252584  https://sofifa.com/player/252584/joe-white/20/...
# 8   18183     252596  https://sofifa.com/player/252596/adam-senior/2...
# 9   18184     252885  https://sofifa.com/player/252885/myles-edmonds...
# 10  18185     252886  https://sofifa.com/player/252886/kwame-osigwe/...
# 11  18187     250737  https://sofifa.com/player/250737/ben-hart/20/1...
# ...

# %% [markdown]
# **Soal ke 7 (Optional, bagi teman teman yang mau menambah nilai)**

# %% [markdown]
# 7. Bacalah 6 data yang ada di file archive, yaitu dari players_15.csv sampai players_20.csv menggunakan looping dan jadikan menjadi 1 dataframe
#
# Hints : Lakukan concat

# %%
import pandas as pd
path = 'D:/Data Science Bootcamp/Homework/Python_Library/'
list_file_name = ['players_15.csv', 'players_16.csv', 'players_17.csv', 'players_18.csv', 'players_19.csv', 'players_20.csv']

main_dataframe = pd.DataFrame(pd.read_csv(list_file_name[0]))

for i in range(1,len(list_file_name)):
    data = pd.read_csv(list_file_name[i])
    df = pd.DataFrame(data)
    main_dataframe = pd.concat([main_dataframe,df], axis = 1)
 
main_dataframe
# Out:
#        sofifa_id                                         player_url  \
# 0       158023.0  https://sofifa.com/player/158023/lionel-messi/...
# 1        20801.0  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         9014.0  https://sofifa.com/player/9014/arjen-robben/15...
# 3        41236.0  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4       167495.0  https://sofifa.com/player/167495/manuel-neuer/...
# ...          ...                                                ...
# 18273        NaN                                                NaN
# 18274        NaN                                                NaN
# 18275        NaN                                                NaN
# 18276        NaN                                                NaN
# 18277        NaN                                                NaN
#
#               short_name                            long_name   age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini  27.0
# ...
